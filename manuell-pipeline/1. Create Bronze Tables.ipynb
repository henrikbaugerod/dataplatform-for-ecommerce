# %% [markdown]
# ##### Task 1
# Ingest customers.json, items.json, and orders.json into three raw tables.
#
# What I want in the end:
# - bronze_customers
# - bronze_items
# - bronze_orders
# - All records loaded from the raw JSON files
# - Nested items array preserved in bronze_orders

# %%
# %sql
USE CATALOG phase_0_workspace;
USE SCHEMA e_commerce;

# %%
# %sql
CREATE OR REPLACE TABLE bronze_customers AS
SELECT * FROM json.`/Volumes/phase_0_workspace/e_commerce/customers`;

SELECT *
FROM bronze_customers;

# %%
# %sql
CREATE OR REPLACE TABLE bronze_items AS
SELECT * FROM json.`/Volumes/phase_0_workspace/e_commerce/items`;

SELECT *
FROM bronze_items;

# %%
# %sql
CREATE OR REPLACE TABLE bronze_orders AS
SELECT * FROM json.`/Volumes/phase_0_workspace/e_commerce/orders`;

SELECT *
FROM bronze_orders;
